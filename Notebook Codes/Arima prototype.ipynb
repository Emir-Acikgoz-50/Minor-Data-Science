# %%
# Import Packages
import pandas as pd
from pandas import datetime
import matplotlib.pyplot as plt
import warnings; warnings.simplefilter('ignore')

# %%
def parser(s):
    return datetime.strptime(s, "%Y-%m-%d")

# %%
# Load Data
data = pd.read_csv('/datc/parcel/notebooks/data/postnl/20201014_300_klanten.csv', parse_dates=[0])

# %%
cust_filter = data['cust_id'] == 'klant_266'
date_filter = data['procesdag'].dt.dayofweek <= 4
data = data.where(date_filter & cust_filter).dropna()

data['procesdag']=pd.to_datetime(data['procesdag'])
data = data.set_index(data.procesdag, drop=True)
data = data['2016-01-01':'2018-01-01']

# %%
data.head()
# Out:
#             procesdag    cust_id  aantal_pakketten  \
# procesdag
# 2016-01-01 2016-01-01  klant_266               0.0
# 2016-01-04 2016-01-04  klant_266             172.0
# 2016-01-05 2016-01-05  klant_266              44.0
# 2016-01-06 2016-01-06  klant_266              54.0
# 2016-01-07 2016-01-07  klant_266              53.0
#
#             aantal_pakketten_volgende_dag validation_column
# procesdag
# 2016-01-01                            0.0             train
# 2016-01-04                           44.0             train
# 2016-01-05                           54.0             train
# 2016-01-06                           53.0             train
# 2016-01-07                           43.0             train

# %%
data.drop(['procesdag'], axis='columns', inplace=True)

# %%
data.head()
# Out:
#               cust_id  aantal_pakketten  aantal_pakketten_volgende_dag  \
# procesdag
# 2016-01-01  klant_266               0.0                            0.0
# 2016-01-04  klant_266             172.0                           44.0
# 2016-01-05  klant_266              44.0                           54.0
# 2016-01-06  klant_266              54.0                           53.0
# 2016-01-07  klant_266              53.0                           43.0
#
#            validation_column
# procesdag
# 2016-01-01             train
# 2016-01-04             train
# 2016-01-05             train
# 2016-01-06             train
# 2016-01-07             train

# %%
data.drop(['aantal_pakketten_volgende_dag'], axis='columns', inplace=True)

# %%
data.head()
# Out:
#               cust_id  aantal_pakketten validation_column
# procesdag
# 2016-01-01  klant_266               0.0             train
# 2016-01-04  klant_266             172.0             train
# 2016-01-05  klant_266              44.0             train
# 2016-01-06  klant_266              54.0             train
# 2016-01-07  klant_266              53.0             train

# %%
data.plot()

# %%
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(data['aantal_pakketten'])

# %%
data_diff = data['aantal_pakketten'].diff()

# %%
data_diff=data_diff[1:]
data_diff.head()
# Out:
# procesdag
# 2016-01-04    172.0
# 2016-01-05   -128.0
# 2016-01-06     10.0
# 2016-01-07     -1.0
# 2016-01-08    -10.0
# Name: aantal_pakketten, dtype: float64

# %%
plot_acf(data_diff)

# %%
data_diff.plot()

# %%
X= data['aantal_pakketten'].values
train= X [0:500] # 500 data train
test = X[500:] #22 test data
predictions = []

# %% [markdown]
# # AR Model

# %%
from statsmodels.tsa.ar_model import AR
from sklearn.metrics import mean_squared_error
model_ar= AR(train)
model_ar_fit=model_ar.fit()

# %%
predictions=model_ar_fit.predict(start=499, end=522)

# %%
plt.plot(test)
plt.plot(predictions, color= 'red')

# %% [markdown]
# # arima

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
#model_arima = ARIMA(train,order=(1,1,1))
#model_arima_fit=model_arima.fit()

# %%
#predictions=model_arima_fit.predict(start=499, end=522)
#predictions

# %%
#plt.plot(test)
#plt.plot(predictions, color= 'red')

# %%
# fit ARIMA model
fig = plt.figure(figsize=(20,8))
model = ARIMA(data['aantal_pakketten'], order=(1,0,0)) 
ax = plt.gca()
results = model.fit() 
plt.plot(data['aantal_pakketten'])
plt.plot(results.fittedvalues, color='red',alpha=1)
ax.legend(['actual', 'Forecast'])
